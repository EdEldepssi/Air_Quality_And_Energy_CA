# %% [markdown]
# # Formatting CARB Statewide Emissions Data

# %% [markdown]
# ## 0. Import Packages

# %%
import pandas as pd

# %% [markdown]
# ## 1. Test Work on PM 2.5 Emissions

# %%
# load data
pm25 = pd.read_csv('../data/CARB Emissions Data/statewide/CARB_cepam_pm2_5.csv')

# %%
pm25.head()
# Out:
#         AREA    SRC_TYPE         CATEGORY  \
# 0  STATEWIDE  STATIONARY  FUEL COMBUSTION
# 1  STATEWIDE  STATIONARY  FUEL COMBUSTION
# 2  STATEWIDE  STATIONARY  FUEL COMBUSTION
# 3  STATEWIDE  STATIONARY  FUEL COMBUSTION
# 4  STATEWIDE  STATIONARY  FUEL COMBUSTION
#
#                            SUBCATEGORY POLLUTANT          SEASON  \
# 0                   ELECTRIC UTILITIES     PM2_5  ANNUAL AVERAGE
# 1                         COGENERATION     PM2_5  ANNUAL AVERAGE
# 2  OIL AND GAS PRODUCTION (COMBUSTION)     PM2_5  ANNUAL AVERAGE
# 3      PETROLEUM REFINING (COMBUSTION)     PM2_5  ANNUAL AVERAGE
# 4         MANUFACTURING AND INDUSTRIAL     PM2_5  ANNUAL AVERAGE
#
#            CONTROL_TYPE      2000      2001      2002  ...      2013  \
# 0  GROWN AND CONTROLLED  7.990296  9.212034  7.435656  ...  6.028129
# 1  GROWN AND CONTROLLED  3.713187  4.270487  3.339253  ...  2.341881
# 2  GROWN AND CONTROLLED  1.971739  1.472658  1.179439  ...  2.095733
# 3  GROWN AND CONTROLLED  4.167303  3.592789  3.267510  ...  3.876679
# 4  GROWN AND CONTROLLED  6.960978  7.400318  5.658637  ...  4.901713
#
#        2014      2015      2016      2017      2018      2019      2020  \
# 0  5.407026  5.307804  4.535730  4.463215  4.236524  4.061526  4.554937
# 1  2.089655  2.098039  1.544696  1.571302  1.533594  1.540158  1.546744
# 2  2.661281  2.656146  2.398715  2.215645  2.155201  2.096769  2.040115
# 3  4.632335  4.436270  4.000298  4.144733  4.167910  4.191088  4.212930
# 4  4.623426  4.499194  4.446501  4.138890  4.201592  4.202737  4.179744
#
#        2021  v1.03_RF3084
# 0  4.490335  v1.03_RF3084
# 1  1.553368  v1.03_RF3084
# 2  1.985155  v1.03_RF3084
# 3  4.236224  v1.03_RF3084
# 4  4.192661  v1.03_RF3084
#
# [5 rows x 30 columns]

# %%
# lowercase columns; drop unnecessary columns
pm25.columns = [col.lower() for col in pm25.columns]
pm25.drop(columns=['area', 'pollutant', 'season', 'control_type', 'v1.03_rf3084'], inplace=True)

# %%
# melt years
pm25 = pd.melt(pm25, id_vars=['src_type', 'category', 'subcategory'], var_name='year', value_name='pm25')

# %%
# cast year as integer
pm25.year = [int(year) for year in pm25.year]

# %%
pm25
# Out:
#                          src_type              category  \
# 0                      STATIONARY       FUEL COMBUSTION
# 1                      STATIONARY       FUEL COMBUSTION
# 2                      STATIONARY       FUEL COMBUSTION
# 3                      STATIONARY       FUEL COMBUSTION
# 4                      STATIONARY       FUEL COMBUSTION
# ...                           ...                   ...
# 1755                       MOBILE  OTHER MOBILE SOURCES
# 1756                       MOBILE  OTHER MOBILE SOURCES
# 1757  NATURAL (NON-ANTHROPOGENIC)       NATURAL SOURCES
# 1758  NATURAL (NON-ANTHROPOGENIC)       NATURAL SOURCES
# 1759  NATURAL (NON-ANTHROPOGENIC)       NATURAL SOURCES
#
#                               subcategory  year        pm25
# 0                      ELECTRIC UTILITIES  2000    7.990296
# 1                            COGENERATION  2000    3.713187
# 2     OIL AND GAS PRODUCTION (COMBUSTION)  2000    1.971739
# 3         PETROLEUM REFINING (COMBUSTION)  2000    4.167303
# 4            MANUFACTURING AND INDUSTRIAL  2000    6.960978
# ...                                   ...   ...         ...
# 1755                       FARM EQUIPMENT  2021    3.245501
# 1756            FUEL STORAGE AND HANDLING  2021    0.000000
# 1757                     BIOGENIC SOURCES  2021    0.000000
# 1758                     GEOGENIC SOURCES  2021    0.000000
# 1759                            WILDFIRES  2021  568.287270
#
# [1760 rows x 5 columns]

# %% [markdown]
# ## 2. Format All Emissions CSVs as DataFrames Stored in Dictionary

# %%
em_types = ['co', 'nh3', 'nox', 'pm', 'pm10', 'pm2_5', 'rog', 'sox', 'tog']
em_df_dict = {}

# %%
for em in em_types:
    # load data
    em_df = pd.read_csv(f'../data/CARB Emissions Data/statewide/CARB_cepam_{em}.csv')
    
    # lowercase columns; drop unnecessary columns
    em_df.columns = [col.lower() for col in em_df.columns]
    em_df.drop(columns=['area', 'pollutant', 'season', 'control_type', 'v1.03_rf3084'], inplace=True)
    
    # melt years and cast year as integer
    em_df = pd.melt(em_df, id_vars=['src_type', 'category', 'subcategory'], var_name='year', value_name=f'{em}')
    em_df.year = [int(year) for year in em_df.year]
    
    # save df in dict
    em_df_dict[f'{em}'] = em_df

# %% [markdown]
# ## 3. Merge All Emissions into Single DataFrame

# %%
# start with carbon monoxide df
all_em_df = em_df_dict['co']

# %%
# merge df's in one at a time, matching on all keys to ensure data integrity
for em in em_types[1:]:
    all_em_df = pd.merge(all_em_df, em_df_dict[f'{em}'], on=['src_type', 'category', 'subcategory', 'year'])

# %%
all_em_df
# Out:
#                          src_type              category  \
# 0                      STATIONARY       FUEL COMBUSTION
# 1                      STATIONARY       FUEL COMBUSTION
# 2                      STATIONARY       FUEL COMBUSTION
# 3                      STATIONARY       FUEL COMBUSTION
# 4                      STATIONARY       FUEL COMBUSTION
# ...                           ...                   ...
# 1755                       MOBILE  OTHER MOBILE SOURCES
# 1756                       MOBILE  OTHER MOBILE SOURCES
# 1757  NATURAL (NON-ANTHROPOGENIC)       NATURAL SOURCES
# 1758  NATURAL (NON-ANTHROPOGENIC)       NATURAL SOURCES
# 1759  NATURAL (NON-ANTHROPOGENIC)       NATURAL SOURCES
#
#                               subcategory  year           co        nh3  \
# 0                      ELECTRIC UTILITIES  2000    87.747861   5.587486
# 1                            COGENERATION  2000    47.060179   2.005656
# 2     OIL AND GAS PRODUCTION (COMBUSTION)  2000    18.723581   0.038666
# 3         PETROLEUM REFINING (COMBUSTION)  2000    10.252644   1.380193
# 4            MANUFACTURING AND INDUSTRIAL  2000   134.593068   2.884717
# ...                                   ...   ...          ...        ...
# 1755                       FARM EQUIPMENT  2021   114.384736   0.071031
# 1756            FUEL STORAGE AND HANDLING  2021     0.000000   0.000000
# 1757                     BIOGENIC SOURCES  2021     0.000000  14.533996
# 1758                     GEOGENIC SOURCES  2021     0.000000  61.794575
# 1759                            WILDFIRES  2021  7172.047622  71.720475
#
#             nox          pm        pm10       pm2_5          rog        sox  \
# 0     66.249218    8.883160    8.273829    7.990296     5.250657   5.706011
# 1     29.043289    4.224099    3.518971    3.713187     2.968590   1.755844
# 2     28.960639    1.984445    1.927553    1.971739     2.540201   7.423263
# 3     47.006641    4.456122    4.229585    4.167303     1.821717  12.819814
# 4     87.507772    7.047467    7.149462    6.960978     4.556243  17.840740
# ...         ...         ...         ...         ...          ...        ...
# 1755  60.007085    3.557842    3.546327    3.245501    12.499444   0.078671
# 1756   0.000000    0.000000    0.000000    0.000000    11.995429   0.000000
# 1757  25.824091    0.000000    0.000000    0.000000  4770.894523   0.000000
# 1758   0.000000    0.000000    0.000000    0.000000    24.906147   0.000000
# 1759  45.396436  697.539979  670.594170  568.287270   502.043319  37.554753
#
#               tog
# 0       33.335160
# 1       16.221292
# 2       25.029807
# 3        3.961066
# 4       21.225969
# ...           ...
# 1755    14.566349
# 1756    11.995430
# 1757  5345.125001
# 1758    91.757860
# 1759   607.919660
#
# [1760 rows x 13 columns]

# %% [markdown]
# ## 4. Save DataFrame to CSV

# %%
all_em_df.to_csv('../data/CARB Emissions Data/statewide/all_em_statewide.csv', index=False)
